# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_excel('FINAL_Global_Slavery_Index_2018_DATA_1549422157.xls', sheet_name=-1)
df
# Out:
#                        Source country   \
# 0                                  NaN
# 1                               COTTON
# 2                           Kazakhstan
# 3                           Tajikistan
# 4                         Turkmenistan
# 5                           Uzbekistan
# 6                                Total
# 7                                  NaN
# 8                               BRICKS
# 9                          Afghanistan
# 10                               India
# 11                             Myanmar
# 12                            Pakistan
# 13                               Total
# 14                                 NaN
# 15      APPAREL & CLOTHING ACCESSORIES
# 16                         Argentina
# 17                              Brazil
# 18                               China
# 19                               India
# 20                            Malaysia
# 21                            Thailand
# 22                             Vietnam
# ...

# %%
#pd.MultiIndex.from_frame(df)

#df

#MultiIndex.from_frame(df, sortorder=None, names=None)

#df.columns.name = 'metrics'    
#df = df.set_index(['tdate', 'tdim']).drop('stringdate', axis=1).unstack('tdate')
#df = df.swaplevel(0,1,axis=1).sort_index(axis=1)

# %%
drop_rows_null_in_source_country = df.loc[df['Source country '].isnull()].index

df = df.drop(drop_rows_null_in_source_country)

# %%
df
# Out:
#                        Source country   \
# 1                               COTTON
# 2                           Kazakhstan
# 3                           Tajikistan
# 4                         Turkmenistan
# 5                           Uzbekistan
# 6                                Total
# 8                               BRICKS
# 9                          Afghanistan
# 10                               India
# 11                             Myanmar
# 12                            Pakistan
# 13                               Total
# 15      APPAREL & CLOTHING ACCESSORIES
# 16                         Argentina
# 17                              Brazil
# 18                               China
# 19                               India
# 20                            Malaysia
# 21                            Thailand
# 22                             Vietnam
# 23                               Total
# 25                              CATTLE
# 26                             Bolivia
# ...

# %%
df.loc[df['Value (in thousands of $US) of imports from at-risk countries'].isnull()]['Source country ']
# Out:
# 1                                 COTTON
# 8                                 BRICKS
# 15        APPAREL & CLOTHING ACCESSORIES
# 25                                CATTLE
# 32                             SUGARCANE
# 37                                  GOLD
# 43                               CARPETS
# 48                                  COAL
# 64                                  RICE
# 69                                TIMBER
# 75                BRAZIL NUTS/ CHESTNUTS
# 79                                 COCOA
# 84                              DIAMONDS
# 88    LAPTOPS, COMPUTERS & MOBILE PHONES
# Name: Source country , dtype: object

# %%
#df.insert(loc, column, value)
#The following code creates a new column, and tells where to put it in the dataframe.
df.insert(1, 'Importing Country Argentina', 'Argentina')
df.insert(7, 'Importing Country Australia', 'Australia')

# %%
#x=births_df.loc[births_df['Gender'] == 'Boys', 'Number']
#totals = df.loc[:,'Source country '].isalpha('Total')
#print(totals)
#df_totals_to_zero = lambda x: df.(totals, 0)
#df.droplevel(, axis=)
#df.append(total_to_blank)
#Source_country.str.replace('Total', '')

# %%
df
# Out:
#                        Source country  Importing Country Argentina  \
# 1                               COTTON                   Argentina
# 2                           Kazakhstan                   Argentina
# 3                           Tajikistan                   Argentina
# 4                         Turkmenistan                   Argentina
# 5                           Uzbekistan                   Argentina
# 6                                Total                   Argentina
# 8                               BRICKS                   Argentina
# 9                          Afghanistan                   Argentina
# 10                               India                   Argentina
# 11                             Myanmar                   Argentina
# 12                            Pakistan                   Argentina
# 13                               Total                   Argentina
# 15      APPAREL & CLOTHING ACCESSORIES                   Argentina
# ...

# %%
#df['Product'] = 0

# %%
#I can use a loc stateent to assign values.  
#Because I am not using a boolean for the rows, I do not need a df in the loc statement
df.insert(1, 'Product', '')
df.loc[1:7, 'Product'] = 'COTTON'
df.loc[8:14, 'Product'] = 'BRICKS'
df.loc[15:24, 'Product'] = 'APPAREL & CLOTHING ACCESSORIES'
df.loc[25:31, 'Product'] = 'CATTLE'
df.loc[32:36, 'Product'] = 'SUGARCANE'
df.loc[37:42, 'Product'] = 'GOLD'
df.loc[43:47, 'Product'] = 'CARPETS'
df.loc[48:63, 'Product'] = 'COAL'
df.loc[64:68, 'Product'] = 'RICE'
df.loc[69:74, 'Product'] = 'TIMBER'
df.loc[75:78, 'Product'] = 'BRAZILE NUTS/ CHESNUTS'
df.loc[79:83, 'Product'] = 'COCOA'
df.loc[84:87, 'Product'] = 'DIAMONDS'
df.loc[88:91, 'Product'] = 'LAPTOPS, COMPUTERS & MOBILE PHONES'

# %%
#Do what is in the preceeding box, or, to have the 'Product' column as the first column to as follows:
#make a list of cottons, with the number of rows of cotton I want to have.
#Make a dataframe of the product column alone
#append the data frame to it. Whatever is appnded second is on the right

# %%
#The code below works.  However, I don
#drop_rows_with_products_as_source_country = df.loc[df['Value (in thousands of $US) of imports from at-risk countries'].isnull()].index

#df = df.drop(drop_rows_with_products_as_source_country)

# %%
df
# Out:
#                        Source country                              Product  \
# 1                               COTTON                              COTTON
# 2                           Kazakhstan                              COTTON
# 3                           Tajikistan                              COTTON
# 4                         Turkmenistan                              COTTON
# 5                           Uzbekistan                              COTTON
# 6                                Total                              COTTON
# 8                               BRICKS                              BRICKS
# 9                          Afghanistan                              BRICKS
# 10                               India                              BRICKS
# 11                             Myanmar                              BRICKS
# 12                            Pakistan                              BRICKS
# ...

# %% [markdown]
# Types of Data
#
# Categorical
# Source country

# %%
df.columns
# Out:
# Index(['Source country ', 'Product', 'Importing Country Argentina',
#        'Value (in thousands of $US) of imports from at-risk countries',
#        'total imports (in thousands of $US)',
#        '% imported from at-risk country ($US)',
#        'Quantity (tonnes)  imported from at-risk country',
#        'total imports (tonnes)', 'Importing Country Australia',
#        '%  imported from at-risk country (tonnes)',
#        ...
#        '% imported from at-risk country ($US).16',
#        'Quantity (tonnes)  imported from at-risk country.16',
#        'total imports (tonnes).16',
#        '%  imported from at-risk country (tonnes).16',
#        'Value (in thousands of $US) of imports from at-risk countries.17',
#        'total imports (in thousands of $US).17',
#        '% imported from at-risk country ($US).17',
#        'Quantity (tonnes)  imported from at-risk country.17',
#        'total imports (tonnes).17',
#        '%  imported from at-risk country (tonnes).17'],
# ...
