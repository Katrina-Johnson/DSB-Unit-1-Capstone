# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
#Step 1. Show the dataframe.
df = pd.read_excel('FINAL_Global_Slavery_Index_2018_DATA_1549422157.xls', sheet_name=-1)
df
# Out:
#                        Source country   \
# 0                                  NaN
# 1                               COTTON
# 2                           Kazakhstan
# 3                           Tajikistan
# 4                         Turkmenistan
# 5                           Uzbekistan
# 6                                Total
# 7                                  NaN
# 8                               BRICKS
# 9                          Afghanistan
# 10                               India
# 11                             Myanmar
# 12                            Pakistan
# 13                               Total
# 14                                 NaN
# 15      APPAREL & CLOTHING ACCESSORIES
# 16                         Argentina
# 17                              Brazil
# 18                               China
# 19                               India
# 20                            Malaysia
# 21                            Thailand
# 22                             Vietnam
# ...

# %%
#Step 2. Show all column names.
df.columns
# Out:
# Index(['Source country ',
#        'Value (in thousands of $US) of imports from at-risk countries',
#        'total imports (in thousands of $US)',
#        '% imported from at-risk country ($US)',
#        'Quantity (tonnes)  imported from at-risk country',
#        'total imports (tonnes)', '%  imported from at-risk country (tonnes)',
#        'Value (in thousands of $US) of imports from at-risk countries.1',
#        'total imports (in thousands of $US).1',
#        '% imported from at-risk country ($US).1',
#        ...
#        '% imported from at-risk country ($US).16',
#        'Quantity (tonnes)  imported from at-risk country.16',
#        'total imports (tonnes).16',
#        '%  imported from at-risk country (tonnes).16',
#        'Value (in thousands of $US) of imports from at-risk countries.17',
#        'total imports (in thousands of $US).17',
#        '% imported from at-risk country ($US).17',
#        'Quantity (tonnes)  imported from at-risk country.17',
# ...

# %%
#Step 3. Show all product names.
product_names_in_source_country_column = df.loc[df['Value (in thousands of $US) of imports from at-risk countries'].isnull()]['Source country ']

print(product_names_in_source_country_column)
# Out:
# 1                                 COTTON
# 8                                 BRICKS
# 15        APPAREL & CLOTHING ACCESSORIES
# 25                                CATTLE
# 32                             SUGARCANE
# 37                                  GOLD
# 43                               CARPETS
# 48                                  COAL
# 64                                  RICE
# 69                                TIMBER
# 75                BRAZIL NUTS/ CHESTNUTS
# 79                                 COCOA
# 84                              DIAMONDS
# 88    LAPTOPS, COMPUTERS & MOBILE PHONES
# Name: Source country , dtype: object

# %%
#Step 4. Create a new Category named 'Product', 
#and make it display as the second category in the dataframe.


#df.insert(loc, column, value)
#The following code creates a new column, and tells where to put it in the dataframe.
df.insert(1, 'Product', '')

#I can use a loc stateent to assign values.  
#Because I am not using a boolean for the rows, I do not need a df in the loc statement
df.loc[1:7, 'Product'] = 'COTTON'
df.loc[8:14, 'Product'] = 'BRICKS'
df.loc[15:24, 'Product'] = 'APPAREL & CLOTHING ACCESSORIES'
df.loc[25:31, 'Product'] = 'CATTLE'
df.loc[32:36, 'Product'] = 'SUGARCANE'
df.loc[37:42, 'Product'] = 'GOLD'
df.loc[43:47, 'Product'] = 'CARPETS'
df.loc[48:63, 'Product'] = 'COAL'
df.loc[64:68, 'Product'] = 'RICE'
df.loc[69:74, 'Product'] = 'TIMBER'
df.loc[75:78, 'Product'] = 'BRAZILE NUTS/ CHESNUTS'
df.loc[79:83, 'Product'] = 'COCOA'
df.loc[84:87, 'Product'] = 'DIAMONDS'
df.loc[88:91, 'Product'] = 'LAPTOPS, COMPUTERS & MOBILE PHONES'

df
# Out:
#                        Source country                              Product  \
# 0                                  NaN
# 1                               COTTON                              COTTON
# 2                           Kazakhstan                              COTTON
# 3                           Tajikistan                              COTTON
# 4                         Turkmenistan                              COTTON
# 5                           Uzbekistan                              COTTON
# 6                                Total                              COTTON
# 7                                  NaN                              COTTON
# 8                               BRICKS                              BRICKS
# 9                          Afghanistan                              BRICKS
# 10                               India                              BRICKS
# 11                             Myanmar                              BRICKS
# ...

# %%
#Step 5. Drop all rows in the category named 'Source country ' that have a product name as their value.

drop_rows_with_products_as_source_country = df.loc[df['Value (in thousands of $US) of imports from at-risk countries'].isnull()].index   
df = df.drop(drop_rows_with_products_as_source_country)
df
# Out:
#        Source country                              Product  \
# 0                  NaN
# 2           Kazakhstan                              COTTON
# 3           Tajikistan                              COTTON
# 4         Turkmenistan                              COTTON
# 5           Uzbekistan                              COTTON
# 6                Total                              COTTON
# 7                  NaN                              COTTON
# 9          Afghanistan                              BRICKS
# 10               India                              BRICKS
# 11             Myanmar                              BRICKS
# 12            Pakistan                              BRICKS
# 13               Total                              BRICKS
# 14                 NaN                              BRICKS
# 16         Argentina        APPAREL & CLOTHING ACCESSORIES
# 17              Brazil      APPAREL & CLOTHING ACCESSORIES
# ...

# %%
#Step 6: Create a script that drops all rows in the 'Source country ' column that have
#NaN value, except the row at y axis index 0.  It countains purchaser country names.
drop_nan_values_in_source_country = df.loc[df['Source country '].isnull()].index[1:,]   
df = df.drop(drop_nan_values_in_source_country)
df
# Out:
#                      Source country                              Product  \
# 0                                NaN
# 2                         Kazakhstan                              COTTON
# 3                         Tajikistan                              COTTON
# 4                       Turkmenistan                              COTTON
# 5                         Uzbekistan                              COTTON
# 6                              Total                              COTTON
# 9                        Afghanistan                              BRICKS
# 10                             India                              BRICKS
# 11                           Myanmar                              BRICKS
# 12                          Pakistan                              BRICKS
# 13                             Total                              BRICKS
# 16                       Argentina        APPAREL & CLOTHING ACCESSORIES
# ...

# %%
#Step 7: Create a script that goes through row 0,
#and replaces all NaN values with the country name 
#that preceed the Nan values to its left.

# %%
#Step 8: (This should be the final step.) Use .MultiIndex()
#to organize the data hierarchically.  
#Purchasing countries should be at level one.
#The six repeating variables should be at level two.
#Indexes should remain the same.

# %%
#pd.MultiIndex.from_frame(df)

#df

#MultiIndex.from_frame(df, sortorder=None, names=None)

#df.columns.name = 'metrics'    
#df = df.set_index(['tdate', 'tdim']).drop('stringdate', axis=1).unstack('tdate')
#df = df.swaplevel(0,1,axis=1).sort_index(axis=1)

# %% [markdown]
# >>> multicol1 = pd.MultiIndex.from_frame([('weight', 'kg'),
# ...                                        ('weight', 'pounds')])
# >>> df_multi_level_cols1 = pd.DataFrame([[1, 2], [2, 4]],
# ...                                     index=['cat', 'dog'],
# ...                                     columns=multicol1)

# %%
#I am trying to create a hierarchically organized index, based on the code above.

multicol1 = pd.MultiIndex.from_frame([('Purchaser', 'Product'), ('Purchaser', 'Value (in thousands of $US) of imports from at-rist countries'), 
                                      ('Purchaser', 'total imports (in thousands of $US') , ('Purchaser', '% imported from at-risk country ($US)'), 
                                      ('Purchaser', 'Quantity (tonnes)  imported from at-risk country', ('Purchaser', 'total imports (tonnes)'), )])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-580-a1ac64946e76> in <module>()
#       1 #I am trying to create a hierarchically organized index, based on the code above.
#       2
# ----> 3 multicol1 = pd.MultiIndex.from_frame([('Purchaser', 'Product'), ('Purchaser', 'Value (in thousands of $US) of imports from at-rist countries'),
#       4                                       ('Purchaser', 'total imports (in thousands of $US') , ('Purchaser', '% imported from at-risk country ($US)'),
#       5                                       ('Purchaser', 'Quantity (tonnes)  imported from at-risk country', ('Purchaser', 'total imports (tonnes)'), )])
#
# AttributeError: type object 'MultiIndex' has no attribute 'from_frame'

# %%
df

# %% [markdown]
# #Things to talk about with Mike:
#
# #drop a row by name, if the index is a word(s)
# #Example: df.drop(df.index[0], inplace=True)
#
# #drop a row by number, if the index is a number
# #Example: df.drop(df.index[0], inplace=True)
#
# #This code works:
# #This will drop the row with the number 1 next to it.
# #Because its index number is 0
# #df = df.drop(df.index[0])
# #df
#
# #This code does not seem to work
# #Question for Mike: Why doesn't this code drop row 8?
# #df = df.drop(df.index[6])
# #df

# %%
#Question for Mike: Why doesn't this code drop row 8?
#df = df.drop(df.index[6])
df

# %% [markdown]
# #This code is not needed.  I have already deleted all rows that #contain a product name in the 'Source country ' column, except row 0,
# #which contains the names of the purchasing countries.
#
# for product in df['Source country ']:
#     if product == 'COTTON':
#         str.replace('COTTON', None)
#         return product
#     elif product == 'BRICKS':
#         str.replace('BRICKS', None)
#         return product
#     elif product == 'APPAREL & CLOTHING ACCESSORIES':
#         str.replace('APPAREL & CLOTHING ACCESSORIES', None)
#         return product
#     elif product == 'CATTLE':
#         str.replace('CATTLE', None)
#         return product
#     elif product == 'SUGARCANE':
#         str.replace('SUGARCANE', None)
#         return product
#     elif product == 'GOLD':
#         str.replace('GOLD', None)
#         return product
#     elif product == 'CARPETS':
#         str.replace('CARPETS', None)
#         return product
#     elif product == 'COAL':
#         str.replace('COAL', None)
#         return product
#     elif product == 'Rice':
#         str.replace('Rice', None)
#         return product
#     elif produce == 'Timber':
#         str.replace('Timber', None)
#         return product
#     elif product == 'BRAZIL NUTS/ CHESTNUTS':
#         str.replace('Timber', None)
#         return product
#     elif product == 'DIAMONDS':
#         str.replace('DIAMONDS', None)
#         return product
#     elif product == 'LAPTOPS, COMPUTERS & MOBILE PHONES':
#         str.replace('LAPTOPS, COMPUTERS & MOBILE PHONES')
#         return product
#     elif product == 'Total':
#         str.replace('Total', None)
#     else:
#         pass
#
# df
