# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
import scipy.stats

# %%
sns.set(color_codes=True)

# %%
#Step 1. Show the dataframe.
df = pd.read_excel('FINAL_Global_Slavery_Index_2018_DATA_1549422157.xls', sheet_name=-1)
df
# Out:
#                        Source country   \
# 0                                  NaN
# 1                               COTTON
# 2                           Kazakhstan
# 3                           Tajikistan
# 4                         Turkmenistan
# 5                           Uzbekistan
# 6                                Total
# 7                                  NaN
# 8                               BRICKS
# 9                          Afghanistan
# 10                               India
# 11                             Myanmar
# 12                            Pakistan
# 13                               Total
# 14                                 NaN
# 15      APPAREL & CLOTHING ACCESSORIES
# 16                         Argentina
# 17                              Brazil
# 18                               China
# 19                               India
# 20                            Malaysia
# 21                            Thailand
# 22                             Vietnam
# ...

# %%
#Step 2. Show all column names.
df.columns
# Out:
# Index(['Source country ',
#        'Value (in thousands of $US) of imports from at-risk countries',
#        'total imports (in thousands of $US)',
#        '% imported from at-risk country ($US)',
#        'Quantity (tonnes)  imported from at-risk country',
#        'total imports (tonnes)', '%  imported from at-risk country (tonnes)',
#        'Value (in thousands of $US) of imports from at-risk countries.1',
#        'total imports (in thousands of $US).1',
#        '% imported from at-risk country ($US).1',
#        ...
#        '% imported from at-risk country ($US).16',
#        'Quantity (tonnes)  imported from at-risk country.16',
#        'total imports (tonnes).16',
#        '%  imported from at-risk country (tonnes).16',
#        'Value (in thousands of $US) of imports from at-risk countries.17',
#        'total imports (in thousands of $US).17',
#        '% imported from at-risk country ($US).17',
#        'Quantity (tonnes)  imported from at-risk country.17',
# ...

# %%
#Step 3. Show all product names.
product_names_in_source_country_column = df.loc[df['Value (in thousands of $US) of imports from at-risk countries'].isnull()]['Source country ']

print(product_names_in_source_country_column)
# Out:
# 1                                 COTTON
# 8                                 BRICKS
# 15        APPAREL & CLOTHING ACCESSORIES
# 25                                CATTLE
# 32                             SUGARCANE
# 37                                  GOLD
# 43                               CARPETS
# 48                                  COAL
# 64                                  RICE
# 69                                TIMBER
# 75                BRAZIL NUTS/ CHESTNUTS
# 79                                 COCOA
# 84                              DIAMONDS
# 88    LAPTOPS, COMPUTERS & MOBILE PHONES
# Name: Source country , dtype: object

# %%
#Step 4. Create a new Category named 'Product', 
#and make it display as the second category in the dataframe.


#df.insert(loc, column, value)
#The following code creates a new column, and tells where to put it in the dataframe.
df.insert(1, 'Product', '')

#I can use a loc stateent to assign values.  
#Because I am not using a boolean for the rows, I do not need a df in the loc statement
df.loc[1:7, 'Product'] = 'COTTON'
df.loc[8:14, 'Product'] = 'BRICKS'
df.loc[15:24, 'Product'] = 'APPAREL & CLOTHING ACCESSORIES'
df.loc[25:31, 'Product'] = 'CATTLE'
df.loc[32:36, 'Product'] = 'SUGARCANE'
df.loc[37:42, 'Product'] = 'GOLD'
df.loc[43:47, 'Product'] = 'CARPETS'
df.loc[48:63, 'Product'] = 'COAL'
df.loc[64:68, 'Product'] = 'RICE'
df.loc[69:74, 'Product'] = 'TIMBER'
df.loc[75:78, 'Product'] = 'BRAZILE NUTS/ CHESNUTS'
df.loc[79:83, 'Product'] = 'COCOA'
df.loc[84:87, 'Product'] = 'DIAMONDS'
df.loc[88:91, 'Product'] = 'LAPTOPS, COMPUTERS & MOBILE PHONES'

df
# Out:
#                        Source country                              Product  \
# 0                                  NaN
# 1                               COTTON                              COTTON
# 2                           Kazakhstan                              COTTON
# 3                           Tajikistan                              COTTON
# 4                         Turkmenistan                              COTTON
# 5                           Uzbekistan                              COTTON
# 6                                Total                              COTTON
# 7                                  NaN                              COTTON
# 8                               BRICKS                              BRICKS
# 9                          Afghanistan                              BRICKS
# 10                               India                              BRICKS
# 11                             Myanmar                              BRICKS
# ...

# %%
#Step 5. Drop all rows in the category named 'Source country ' that have a product name as their value.

drop_rows_with_products_as_source_country = df.loc[df['Value (in thousands of $US) of imports from at-risk countries'].isnull()].index   
df = df.drop(drop_rows_with_products_as_source_country)
df
# Out:
#        Source country                              Product  \
# 0                  NaN
# 2           Kazakhstan                              COTTON
# 3           Tajikistan                              COTTON
# 4         Turkmenistan                              COTTON
# 5           Uzbekistan                              COTTON
# 6                Total                              COTTON
# 7                  NaN                              COTTON
# 9          Afghanistan                              BRICKS
# 10               India                              BRICKS
# 11             Myanmar                              BRICKS
# 12            Pakistan                              BRICKS
# 13               Total                              BRICKS
# 14                 NaN                              BRICKS
# 16         Argentina        APPAREL & CLOTHING ACCESSORIES
# 17              Brazil      APPAREL & CLOTHING ACCESSORIES
# ...

# %%
#Step 6: Create a script that drops all rows in the 'Source country ' column that have
#NaN value, except the row at y (top-bottom) axis index 0.  It countains purchaser country names.
drop_nan_values_in_source_country = df.loc[df['Source country '].isnull()].index[1:,]   
df = df.drop(drop_nan_values_in_source_country)
df
# Out:
#                      Source country                              Product  \
# 0                                NaN
# 2                         Kazakhstan                              COTTON
# 3                         Tajikistan                              COTTON
# 4                       Turkmenistan                              COTTON
# 5                         Uzbekistan                              COTTON
# 6                              Total                              COTTON
# 9                        Afghanistan                              BRICKS
# 10                             India                              BRICKS
# 11                           Myanmar                              BRICKS
# 12                          Pakistan                              BRICKS
# 13                             Total                              BRICKS
# 16                       Argentina        APPAREL & CLOTHING ACCESSORIES
# ...

# %%
#Step 7: Create a separate dataframes for each country. To see how each line of code works
#look at the documentation in Step 9.

Argentina_df = df.iloc[1:91, 2:8]
Argentina_df.insert(0, 'Purchasing Country', 'Argentina')
Argentina_df.insert(1, 'Product', df[['Product']].copy())
Argentina_df.insert(2, 'Source country ', df[['Source country ']].copy())


sns.set(color_codes=True)
Argentina_df
# Out:
#    Purchasing Country                             Product  \
# 2           Argentina                              COTTON
# 3           Argentina                              COTTON
# 4           Argentina                              COTTON
# 5           Argentina                              COTTON
# 6           Argentina                              COTTON
# 9           Argentina                              BRICKS
# 10          Argentina                              BRICKS
# 11          Argentina                              BRICKS
# 12          Argentina                              BRICKS
# 13          Argentina                              BRICKS
# 16          Argentina      APPAREL & CLOTHING ACCESSORIES
# 17          Argentina      APPAREL & CLOTHING ACCESSORIES
# 18          Argentina      APPAREL & CLOTHING ACCESSORIES
# 19          Argentina      APPAREL & CLOTHING ACCESSORIES
# 20          Argentina      APPAREL & CLOTHING ACCESSORIES
# ...

# %%
#Step 8. Show all of the purchasing countries, 
#so that I can make a separete dataframe for each.
#Note: Use the iloc index numbers to start and end each dataframe.

#This piece of code will allow me to check any y axis index position
#in a single row (same as x axis or across) in a data frame.  
#The first number is the x (across) axis index position. 
#The second number is the y (same as top-bottoom) axis index position.  

#>>> x = pd.Series([0, 1, 2])
#>>> x.all()   # because one element is zero
#False
#>>> x.any()   # because one (or more) elements are non-zero
#True

purchasing_country_1=pd.Series((df.iloc[0, 2]))
purchasing_country_2=pd.Series(df.iloc[0, 8])
purchasing_country_3=pd.Series(df.iloc[0, 14])
purchasing_country_4=pd.Series(df.iloc[0, 20])
purchasing_country_5=pd.Series(df.iloc[0, 26])
purchasing_country_6=pd.Series(df.iloc[0, 32])
purchasing_country_7=pd.Series(df.iloc[0, 38])
purchasing_country_8=pd.Series(df.iloc[0, 44])
purchasing_country_9=pd.Series(df.iloc[0, 50])
purchasing_country_10=pd.Series(df.iloc[0, 56])
purchasing_country_11=pd.Series(df.iloc[0, 62])
purchasing_country_12=pd.Series(df.iloc[0, 68])
purchasing_country_13=pd.Series(df.iloc[0, 74])
purchasing_country_14=pd.Series(df.iloc[0, 80])
purchasing_country_15=pd.Series(df.iloc[0, 86])
purchasing_country_16=pd.Series(df.iloc[0, 92])
purchasing_country_17=pd.Series(df.iloc[0, 98])
purchasing_country_18=pd.Series(df.iloc[0, 104])


print(purchasing_country_1.any())
print(purchasing_country_2.any())
print(purchasing_country_3.any())
print(purchasing_country_4.any())
print(purchasing_country_5.any())
print(purchasing_country_6.any())
print(purchasing_country_7.any())
print(purchasing_country_8.any())
print(purchasing_country_9.any())
print(purchasing_country_10.any())
print(purchasing_country_11.any())
print(purchasing_country_12.any())
print(purchasing_country_13.any())
print(purchasing_country_14.any())
print(purchasing_country_15.any())
print(purchasing_country_16.any())
print(purchasing_country_17.any())
print(purchasing_country_18.any())
# Out:
# Argentina
# Australia
# Brazil
# Canada
# China
# France
# Germany
# Indonesia
# Italy
# Japan
# South Korea
# Mexico
# Russia
# Saudi Arabia
# India
# Turkey
# UK
# US

# %%
#Step 9. Create a separate dataframe for Australia,
#and associate it with its related variables(columns),
#and data points(rows).  (Start with Australia, as example code for all other countrys' dataframes).
Australia_df = df.iloc[1:91, 8:14]

#Step 9b. Create a column called 'Purchasing Country' in the dataframe Australia_df,
#set the country as 'Australia' for index position 0 in all of the rows for that column.
Australia_df.insert(0, 'Purchasing Country', 'Australia')

#Step 9c. Insert the 'Product' column and all variables for each row in that column,
#from the original df into Australia_df at index position 1.
Australia_df.insert(1, 'Product', df[['Product']].copy())


#Step 9d. Insert the 'Source country ' column and all variables for each row in that column,
#from the original df into Australia_df at index position 2.
Australia_df.insert(2, 'Source country ', df[['Source country ']].copy())



#Step 9e.  Rename the columns in Australia_df so that their names are identical to the column names 
#in the original dataframe.
Australia_df = Australia_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.1' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).1' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).1' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.1' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).1' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).1' : '%  imported from at-risk country (tonnes)'})

sns.set(color_codes=True)
#Australia_df

# %%
#Step 10. Create Brazil_df.

Brazil_df = df.iloc[1:91, 14:20]
Brazil_df.insert(0, 'Purchasing Country', 'Brazil')
Brazil_df.insert(1, 'Product', df[['Product']].copy())
Brazil_df.insert(2, 'Source country ', df[['Source country ']].copy())
Brazil_df = Brazil_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.2' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).2' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).2' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.2' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).2' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).2' : '%  imported from at-risk country (tonnes)'})

sns.set(color_codes=True)
#Brazil_df

# %%
#Step 11. Create Canada_df.

Canada_df = df.iloc[1:91, 20:26]
Canada_df.insert(0, 'Purchasing Country', 'Canada')
Canada_df.insert(1, 'Product', df[['Product']].copy())
Canada_df.insert(2, 'Source country ', df[['Source country ']].copy())
Canada_df = Canada_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.3' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).3' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).3' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.3' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).3' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).3' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
#Canada_df

# %%
#Step 12. Create China_df.

China_df = df.iloc[1:91, 26:32]
China_df.insert(0, 'Purchasing Country', 'China')
China_df.insert(1, 'Product', df[['Product']].copy())
China_df.insert(2, 'Source country ', df[['Source country ']].copy())
China_df = China_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.4' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).4' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).4' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.4' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).4' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).4' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
#China_df

# %%
#Step 13. Create France_df.

France_df = df.iloc[1:91, 32:38]
France_df.insert(0, 'Purchasing Country', 'France')
France_df.insert(1, 'Product', df[['Product']].copy())
France_df.insert(2, 'Source country ', df[['Source country ']].copy())
France_df = France_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.5' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).5' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).5' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.5' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).5' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).5' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
#France_df

# %%
#Step 14. Create Germany_df.

Germany_df = df.iloc[1:91, 38:44]
Germany_df.insert(0, 'Purchasing Country', 'Germany')
Germany_df.insert(1, 'Product', df[['Product']].copy())
Germany_df.insert(2, 'Source country ', df[['Source country ']].copy())
Germany_df = Germany_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.6' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).6' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).6' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.6' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).6' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).6' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
#Germany_df

# %%
#Step 15. Create Indonesia_df.

Indonesia_df = df.iloc[1:91, 44:50]
Indonesia_df.insert(0, 'Purchasing Country', 'Indonesia')
Indonesia_df.insert(1, 'Product', df[['Product']].copy())
Indonesia_df.insert(2, 'Source country ', df[['Source country ']].copy())
Indonesia_df = Indonesia_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.7' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).7' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).7' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.7' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).7' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).7' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
#Indonesia_df

# %%
#Step 16. Create Italy_df.

Italy_df = df.iloc[1:91, 50:56]
Italy_df.insert(0, 'Purchasing Country', 'Italy')
Italy_df.insert(1, 'Product', df[['Product']].copy())
Italy_df.insert(2, 'Source country ', df[['Source country ']].copy())
Italy_df = Italy_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.8' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).8' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).8' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.8' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).8' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).8' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
#Italy_df

# %%
#Step 17. Create Japan_df.

Japan_df = df.iloc[1:91, 56:62]
Japan_df.insert(0, 'Purchasing Country', 'Japan')
Japan_df.insert(1, 'Product', df[['Product']].copy())
Japan_df.insert(2, 'Source country ', df[['Source country ']].copy())
Japan_df = Japan_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.9' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).9' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).9' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.9' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).9' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).9' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
#Japan_df

# %%
#Step 18. Create South_Korea_df.

South_Korea_df = df.iloc[1:91, 62:68]
South_Korea_df.insert(0, 'Purchasing Country', 'South Korea')
South_Korea_df.insert(1, 'Product', df[['Product']].copy())
South_Korea_df.insert(2, 'Source country ', df[['Source country ']].copy())
South_Korea_df = South_Korea_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.10' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).10' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).10' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.10' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).10' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).10' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
#South_Korea_df

# %%
#Step 19. Create Mexico_df.

Mexico_df = df.iloc[1:91, 68:74]
Mexico_df.insert(0, 'Purchasing Country', 'Mexico')
Mexico_df.insert(1, 'Product', df[['Product']].copy())
Mexico_df.insert(2, 'Source country ', df[['Source country ']].copy())
Mexico_df = Mexico_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.11' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).11' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).11' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.11' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).11' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).11' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
#Mexico_df

# %%
#Step 20. Create Russia_df.

Russia_df = df.iloc[1:91, 74:80]
Russia_df.insert(0, 'Purchasing Country', 'Russia')
Russia_df.insert(1, 'Product', df[['Product']].copy())
Russia_df.insert(2, 'Source country ', df[['Source country ']].copy())
Russia_df = Russia_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.12' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).12' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).12' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.12' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).12' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).12' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
#Russia_df

# %%
#Step 21. Create Saudi_Arabia_df.

Saudi_Arabia_df = df.iloc[1:91, 80:86]
Saudi_Arabia_df.insert(0, 'Purchasing Country', 'Saudi Arabia')
Saudi_Arabia_df.insert(1, 'Product', df[['Product']].copy())
Saudi_Arabia_df.insert(2, 'Source country ', df[['Source country ']].copy())
Saudi_Arabia_df = Saudi_Arabia_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.13' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).13' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).13' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.13' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).13' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).13' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
#Saudi_Arabia_df

# %%
#Step 22. Create India_df.

India_df = df.iloc[1:91, 86:92]
India_df.insert(0, 'Purchasing Country', 'India')
India_df.insert(1, 'Product', df[['Product']].copy())
India_df.insert(2, 'Source country ', df[['Source country ']].copy())
India_df = India_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.14' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).14' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).14' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.14' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).14' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).14' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
#India_df

# %%
#Step 23. Create Trukey_df.

Turkey_df = df.iloc[1:91, 92:98]
Turkey_df.insert(0, 'Purchasing Country', 'Turkey')
Turkey_df.insert(1, 'Product', df[['Product']].copy())
Turkey_df.insert(2, 'Source country ', df[['Source country ']].copy())
Turkey_df = Turkey_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.15' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).15' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).15' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.15' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).15' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).15' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
#Turkey_df

# %%
#Step 24. Create UK_df.


UK_df = df.iloc[1:91, 98:104]
UK_df.insert(0, 'Purchasing Country', 'UK')
UK_df.insert(1, 'Product', df[['Product']].copy())
UK_df.insert(2, 'Source country ', df[['Source country ']].copy())
UK_df = UK_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.16' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).16' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).16' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.16' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).16' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).16' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
#UK_df

# %%
#Step 25. Create US_df.

US_df = df.iloc[1:91, 104:110]
US_df.insert(0, 'Purchasing Country', 'US')
US_df.insert(1, 'Product', df[['Product']].copy())
US_df.insert(2, 'Source country ', df[['Source country ']].copy())
US_df = US_df.rename(index=str, columns={'Value (in thousands of $US) of imports from at-risk countries.17' : 'Value (in thousands of $US) of imports from at-risk countries', 
                                            'total imports (in thousands of $US).17' : 'total imports (in thousands of $US)',
                                            '% imported from at-risk country ($US).17' : '% imported from at-risk country ($US)',
                                            'Quantity (tonnes)  imported from at-risk country.17' : 'Quantity (tonnes)  imported from at-risk country',
                                            'total imports (tonnes).17' : 'total imports (tonnes)',
                                            '%  imported from at-risk country (tonnes).17' : '%  imported from at-risk country (tonnes)'})
sns.set(color_codes=True)
US_df
# Out:
#    Purchasing Country                             Product  \
# 2                  US                              COTTON
# 3                  US                              COTTON
# 4                  US                              COTTON
# 5                  US                              COTTON
# 6                  US                              COTTON
# 9                  US                              BRICKS
# 10                 US                              BRICKS
# 11                 US                              BRICKS
# 12                 US                              BRICKS
# 13                 US                              BRICKS
# 16                 US      APPAREL & CLOTHING ACCESSORIES
# 17                 US      APPAREL & CLOTHING ACCESSORIES
# 18                 US      APPAREL & CLOTHING ACCESSORIES
# 19                 US      APPAREL & CLOTHING ACCESSORIES
# 20                 US      APPAREL & CLOTHING ACCESSORIES
# ...

# %%
#Step 26. Concatenate all dataframes that begin with a country name.

cc_df = pd.concat([Argentina_df, Australia_df, Brazil_df, Canada_df, China_df, 
           France_df, Germany_df, Indonesia_df, Italy_df, Japan_df, 
           South_Korea_df, Mexico_df, Russia_df, Saudi_Arabia_df, 
           India_df, Turkey_df, UK_df, US_df], ignore_index=True, sort=False)

cc_df
# Out:
#      Purchasing Country                             Product  \
# 0             Argentina                              COTTON
# 1             Argentina                              COTTON
# 2             Argentina                              COTTON
# 3             Argentina                              COTTON
# 4             Argentina                              COTTON
# 5             Argentina                              BRICKS
# 6             Argentina                              BRICKS
# 7             Argentina                              BRICKS
# 8             Argentina                              BRICKS
# 9             Argentina                              BRICKS
# 10            Argentina      APPAREL & CLOTHING ACCESSORIES
# 11            Argentina      APPAREL & CLOTHING ACCESSORIES
# 12            Argentina      APPAREL & CLOTHING ACCESSORIES
# 13            Argentina      APPAREL & CLOTHING ACCESSORIES
# 14            Argentina      APPAREL & CLOTHING ACCESSORIES
# ...

# %%
#Step 27. Create histograms of categorical variables.


all_cotton = cc_df.loc[(cc_df['Product'] == 'COTTON'), 
                       'Value (in thousands of $US) of imports from at-risk countries']

sns.distplot(all_cotton, kde=False, rug=False, color='b')
plt.show()
# Out:
# /Users/katrinajohnson/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-182-e081239c056e> in <module>()
#       5                        'Value (in thousands of $US) of imports from at-risk countries']
#       6
# ----> 7 sns.distplot(all_cotton, kde=False, rug=False, color='b')
#       8 plt.show()
#
# ...
